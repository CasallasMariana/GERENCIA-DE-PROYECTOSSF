# %% [markdown]
# <a href="https://colab.research.google.com/github/CasallasMariana/GERENCIA-DE-PROYECTOSSF/blob/main/Sesi%C3%B3n2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SESIÓN 2 - 03-09-2026
#
# PM BOOK
# 48MIL REVISIONES ES RESALTADA
# EFICIENCIA, 6 PRINCIPIOS, ANTERIORMENTE ERAN 12, MÁS ÁGIL Y PRÁCTICA
# CONCEPTOS FLEXIBLES
# TAILORING, AJUSTAR EL ENFOQUE AL ENTORNO ESCALA Y CARACTERÍSTICAS DEL PROYECTO
# PASOS: SELECCIONAR - ORGANIZACIÓN - PROYECTO - MEJORA CONTINUA
# MONITOREO DE COSTO Y CRONOGRAMA PARA LA PARTES
# CPI - SPI - EAC
# TCPI VELOCIDAD QUE NECESITA MANTENER
# 1=ESFUERZO EQUILIBRADO
# SUPERIOR A 1.0= TRABAJO MÁS DURO Y EFICIENTE
# CIERRE FORMAL,INFORME FINAL
# REUNIONES DE RETROSPECTIVA
# INFORME LECCIONES APRENDIDAS
# ENTREGA FORMAL
