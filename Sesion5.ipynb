# %% [markdown]
# <a href="https://colab.research.google.com/github/CasallasMariana/GERENCIA-DE-PROYECTOSSF/blob/main/Sesion5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SESIÓN 5 - 09-09-2026
#
# La excelencia técnica ya no basta
#
# Comprender una verdad fundamental, es más que redactar líneas de código
#
# PMBOK: Ofrece un enfoque simplificado, 5 áreas de enfoque prácticas,
# Portafolios y operaciones: la gestión de cartera vincula la estrategia con la ejecución
# Entrega de valor: el software por si solo es un resultado.
# "El valor por unidad de inversión es el indicador definitivo del éxito de un proyecto"
# Se debe crear un software rentable para que sea exitoso
# Tres pasos:
# Necesidad comercial, objetivos medibles, Éxito métricas concretas y criterios de aceptación claros
# Caso de Negocio: viabilidad económica para establecer la validez de los beneficios de negocio de un proyecto.
# Acta constitutiva, sin esto la idea de un software, no es más que una idea
#
# Entregarles del proyecto, aseguran predecibilidas y éxito en el proyecto
