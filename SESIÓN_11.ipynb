# %% [markdown]
# <a href="https://colab.research.google.com/github/CasallasMariana/GERENCIA-DE-PROYECTOSSF/blob/main/SESI%C3%93N_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 16/09/2026
# SESIÓN 11
# Dominio de desempeño financiero
# Las empresas definen el valor de muchas maneras, el desempeño financiero no se trata solo de cortar costos
# capEX vs OPEX
# Métricas de viabilidad financiera
# ![{CA60CBED-7D2E-4223-92F3-BC9D6D312ADC}.png](data:image/png;base64,...)
#
# ![{1A7178FF-39D8-4638-9B56-731D5B93DDC2}.png](data:image/png;base64,...)
#
# ![{39BC8CEC-E362-4B1D-9BAC-D7D7A98DED80}.png](data:image/png;base64,...)
#
# ![{9A1DE55D-0652-4F09-9893-CAB7637396E2}.png](data:image/png;base64,...)
